# %% [markdown]
# *N'A FINALEMENT PAS SERVI.* Ce document sert à joindre la base de données sur le type de média à celle regroupant les hésitants et ajouter après concertation avec mon directeur de recherche. Voici la base de données hésitation : https://docs.google.com/spreadsheets/d/1MNNtEkNPcpRjY0xucPTx0XlwmhRb5AERE4GCn-gObLU/edit?usp=sharing

# %%
import pandas as pd
import numpy as np

# %%
fichier_listemedia_h = "/media-hesitation2.csv"
fichier_listemedia = "/listemedia.csv"

# %%
listemedia_hesitation = pd.read_csv(fichier_listemedia_h)
listemedia = pd.read_csv(fichier_listemedia)

# %%
listemedia_hesitation
# Out:
#               media_url   Type_media Ville du siège social
# 0    www.iheartradio.ca    non-média              Montréal
# 1    www.meteomedia.com     national              Montréal
# 2           zone911.com     national              en ligne
# 3     www.droit-inc.com     national              Montréal
# 4      www.neomedia.com     national                   NaN
# ..                  ...          ...                   ...
# 90         fr.yahoo.com  hors Québec           hors Québec
# 91     m.zonebourse.com  hors Québec           hors Québec
# 92     tonpetitlook.com    non-média                   NaN
# 93  www.actusmedias.com     national              en ligne
# 94         www.atuvu.ca    non-média                   NaN
#
# [95 rows x 3 columns]

# %%
listemedia
# Out:
#                       media_url      Type_media Ville du siège social
# 0           ici.radio-canada.ca        national              Montréal
# 1               www.lapresse.ca        national              Montréal
# 2     www.journaldemontreal.com        national              Montréal
# 3       www.journaldequebec.com        national                Québec
# 4              www.lesoleil.com  local/regional                Québec
# ...                         ...             ...                   ...
# 1435      www.yvelines-infos.fr       non media                   NaN
# 1436            www.zayactu.org     hors Québec           hors Québec
# 1437         www.zegreenweb.com     hors Québec           hors Québec
# 1438               www.zeste.ca       non media                   NaN
# 1439               xbox-mag.net       non media                   NaN
#
# [1440 rows x 3 columns]

# %%
listemedia.update(listemedia_hesitation, overwrite=False)

# %%
listemedia
# Out:
#                       media_url      Type_media Ville du siège social
# 0           ici.radio-canada.ca        national              Montréal
# 1               www.lapresse.ca        national              Montréal
# 2     www.journaldemontreal.com        national              Montréal
# 3       www.journaldequebec.com        national                Québec
# 4              www.lesoleil.com  local/regional                Québec
# ...                         ...             ...                   ...
# 1435      www.yvelines-infos.fr       non media                   NaN
# 1436            www.zayactu.org     hors Québec           hors Québec
# 1437         www.zegreenweb.com     hors Québec           hors Québec
# 1438               www.zeste.ca       non media                   NaN
# 1439               xbox-mag.net       non media                   NaN
#
# [1440 rows x 3 columns]
