# %% [markdown]
# Ceci est un document test pour lire les informations de mes résultats de recherche sur Google News.

# %%
import pandas as pd
import numpy as np

# %%
fichier_listemedia = "/content/listemedia_test.csv"
fichier_fulldata = "/content/full-data-nomediatype-dont-import.csv"

# %%
listemedia = pd.read_csv(fichier_listemedia)
fulldata = pd.read_csv(fichier_fulldata)

# %%
listemedia
# Out:
#                       media_url      Type_media Ville du siège social
# 0           ici.radio-canada.ca        national              Montréal
# 1               www.lapresse.ca        national              Montréal
# 2     www.journaldemontreal.com        national              Montréal
# 3       www.journaldequebec.com        national                Québec
# 4              www.lesoleil.com  local/regional                Québec
# ...                         ...             ...                   ...
# 1435      www.yvelines-infos.fr             NaN                   NaN
# 1436            www.zayactu.org             NaN                   NaN
# 1437         www.zegreenweb.com             NaN                   NaN
# 1438               www.zeste.ca             NaN                   NaN
# 1439               xbox-mag.net             NaN                   NaN
#
# [1440 rows x 3 columns]

# %%
fulldata

# %%
fulldata.loc[fulldata["media_url"]=="ici.radio-canada.ca"]
# Out:
#                            Villes             Mots-clés  position du média  \
# 197                    Acton Vale     maire OR mairesse                 23
# 270                    Acton Vale    autobus OR tramway                 10
# 272                    Acton Vale    autobus OR tramway                 12
# 321                    Acton Vale  élection OR campagne                 11
# 368                    Acton Vale          "arme à feu"                  8
# ...                           ...                   ...                ...
# 101860  Notre-Dame-du-Mont-Carmel              accident                 18
# 101864  Notre-Dame-du-Mont-Carmel              accident                 22
# 101866  Notre-Dame-du-Mont-Carmel              accident                 24
# 101876  Notre-Dame-du-Mont-Carmel         décès OR mort                  9
# 101901  Notre-Dame-du-Mont-Carmel              incendie                  9
#
#                Nom du média  \
# 197     ICI.Radio-Canada.ca
# ...

# %%
fulldata["media_type"] = np.where(fulldata["media_url"].reset_index(drop=True) == listemedia["media_url"].reset_index(drop=True), listemedia["Type_media"], False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-f489cc4584e7> in <module>()
# ----> 1 fulldata["media_type"] = np.where(fulldata["media_url"].reset_index(drop=True) == listemedia["media_url"].reset_index(drop=True), listemedia["Type_media"], False)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/arraylike.py in __eq__(self, other)
#      30     @unpack_zerodim_and_defer("__eq__")
#      31     def __eq__(self, other):
# ---> 32         return self._cmp_method(other, operator.eq)
#      33
#      34     @unpack_zerodim_and_defer("__ne__")
#
# ...

# %%
#fulldata['media_type'] = fulldata.merge(listemedia, left_on='media_url', right_on='media_url')["Type_media"]

# %%
fulldata.merge(listemedia, on = "media_url", how = "left")
# Out:
#                            Villes Mots-clés  position du média  \
# 0                      Acton Vale  accident                  1
# 1                      Acton Vale  accident                  2
# 2                      Acton Vale  accident                  3
# 3                      Acton Vale  accident                  4
# 4                      Acton Vale  accident                  5
# ...                           ...       ...                ...
# 101910  Notre-Dame-du-Mont-Carmel  incendie                 18
# 101911  Notre-Dame-du-Mont-Carmel  incendie                 19
# 101912  Notre-Dame-du-Mont-Carmel  incendie                 20
# 101913  Notre-Dame-du-Mont-Carmel  incendie                 21
# 101914  Notre-Dame-du-Mont-Carmel  incendie                  2
#
#                                       Nom du média  \
# 0                               VINGT 55 Média web
# 1             La Tribune - Groupe Capitales Médias
# 2                               VINGT 55 Média web
# ...

# %%
fulldata.drop(columns=["media_type"])
# Out:
#                            Villes Mots-clés  position du média  \
# 0                      Acton Vale  accident                  1
# 1                      Acton Vale  accident                  2
# 2                      Acton Vale  accident                  3
# 3                      Acton Vale  accident                  4
# 4                      Acton Vale  accident                  5
# ...                           ...       ...                ...
# 101910  Notre-Dame-du-Mont-Carmel  incendie                 18
# 101911  Notre-Dame-du-Mont-Carmel  incendie                 19
# 101912  Notre-Dame-du-Mont-Carmel  incendie                 20
# 101913  Notre-Dame-du-Mont-Carmel  incendie                 21
# 101914  Notre-Dame-du-Mont-Carmel  incendie                  2
#
#                                       Nom du média  \
# 0                               VINGT 55 Média web
# 1             La Tribune - Groupe Capitales Médias
# 2                               VINGT 55 Média web
# ...

# %%
fulldata_1 = fulldata.drop(columns=["media_type"])

# %%
fulldata_2 = fulldata_1.merge(listemedia, on = "media_url", how = "left")

# %%
fulldata_2.tail(10)
# Out:
#                            Villes Mots-clés  position du média  \
# 101905  Notre-Dame-du-Mont-Carmel  incendie                 13
# 101906  Notre-Dame-du-Mont-Carmel  incendie                 14
# 101907  Notre-Dame-du-Mont-Carmel  incendie                 15
# 101908  Notre-Dame-du-Mont-Carmel  incendie                 16
# 101909  Notre-Dame-du-Mont-Carmel  incendie                 17
# 101910  Notre-Dame-du-Mont-Carmel  incendie                 18
# 101911  Notre-Dame-du-Mont-Carmel  incendie                 19
# 101912  Notre-Dame-du-Mont-Carmel  incendie                 20
# 101913  Notre-Dame-du-Mont-Carmel  incendie                 21
# 101914  Notre-Dame-du-Mont-Carmel  incendie                  2
#
#                                     Nom du média  \
# 101905                                 La Presse
# 101906                               Coup d'Oeil
# 101907  Le Nouvelliste - Groupe Capitales Médias
# 101908                  L'Hebdo du Saint-Maurice
# ...
