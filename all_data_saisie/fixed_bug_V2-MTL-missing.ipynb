# %% [markdown]
# Ceci est un document test pour lire les informations de mes résultats de recherche sur Google News.

# %%
import pandas as pd
# Out:
# /Users/nicolasst-germain/.pyenv/versions/3.7.3/lib/python3.7/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
fichier_listemedia = "/Users/nicolasst-germain/Documents/GitHub/audit_google_news/all_data_saisie/liste-media/listemedia_domaine.csv"
fichier_listemedia_V2 = "/Users/nicolasst-germain/Documents/GitHub/audit_google_news/all_data_saisie/liste-media/listemedia_V2.csv"

# %%
listemedia = pd.read_csv(fichier_listemedia)
V2 = pd.read_csv(fichier_listemedia_V2)

# %%
listemedia
# Out:
#                                     media_url   Type_media  \
# 0     www.ciusss-capitalenationale.gouv.qc.ca    non media
# 1                         www.msss.gouv.qc.ca    non media
# 2                           www.sq.gouv.qc.ca    non media
# 3                      www.ville.quebec.qc.ca    non media
# 4       www.auvergne-rhone-alpes.ars.sante.fr    non media
# ...                                       ...          ...
# 1435                           lequotidien.sn  hors Québec
# 1436                              lapresse.tn  hors Québec
# 1437                                viaatv.tv  hors Québec
# 1438                            lecourrier.vn  hors Québec
# 1439                    lejournaldemayotte.yt  hors Québec
#
#      Ville du siège social                                  domaine
# 0                      NaN  www.ciusss-capitalenationale.gouv.qc.ca
# 1                      NaN                      www.msss.gouv.qc.ca
# ...

# %%
V2
# Out:
#                       media_url
# 0           ici.radio-canada.ca
# 1               www.lapresse.ca
# 2     www.journaldemontreal.com
# 3       www.journaldequebec.com
# 4              www.lesoleil.com
# ...                         ...
# 1454           www.fredzone.org
# 1455          www.info-tours.fr
# 1456           www.artsixmic.fr
# 1457           www.handirect.fr
# 1458            www.arabnews.fr
#
# [1459 rows x 1 columns]

# %%
V2_bug_fix = V2.merge(listemedia, on = "media_url", how = "left")
V2_bug_fix.to_csv("V2_listemedia_fixed.csv")
