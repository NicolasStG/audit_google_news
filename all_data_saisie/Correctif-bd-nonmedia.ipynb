# %%
import pandas as pd
# Out:
# /Users/nicolasst-germain/.pyenv/versions/3.7.3/lib/python3.7/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
fichier_fulldata = "/Users/nicolasst-germain/Documents/GitHub/audit_google_news/all_data_saisie/all_data/output_full_data_without_mediatype.csv"
fichier_listemedia = "/Users/nicolasst-germain/Documents/GitHub/audit_google_news/all_data_saisie/liste-media/V2_listemedia_fixed.csv"

# %%
full_data = pd.read_csv(fichier_fulldata)
listemedia = pd.read_csv(fichier_listemedia)

# %%
full_data
# Out:
#             Villes Mots-clés position du média  \
# 0       Acton Vale  accident                 1
# 1       Acton Vale  accident                 2
# 2       Acton Vale  accident                 3
# 3       Acton Vale  accident                 4
# 4       Acton Vale  accident                 5
# ...            ...       ...               ...
# 490516     Windsor   déficit                 4
# 490517     Windsor   déficit                 5
# 490518     Windsor   déficit                 6
# 490519     Windsor   déficit                 7
# 490520     Windsor   déficit                 8
#
#                                       Nom du média  \
# 0                               VINGT 55 Média web
# 1             La Tribune - Groupe Capitales Médias
# 2                               VINGT 55 Média web
# 3                                    TVA Nouvelles
# 4       La Voix de l'est - Groupe Capitales Médias
# ...                                            ...
# 490516                                  La Tribune
# 490517                         ICI.Radio-Canada.ca
# 490518                         ICI.Radio-Canada.ca
# 490519                                  La Tribune
# 490520                             Radio-Canada.ca
#
#                                        Titre de l'article Date de publication  \
# 0       Un motoneigiste blessé récupéré dans un sentie...          2021-01-26
# 1       Un véhicule heurte volontairement un autre | J...          2021-03-24
# 2       Accident délit de fuite et arrestation pour fa...          2021-02-27
# 3       La SQ démantèle un stratagème frauduleux sur l...          2021-07-01
# 4       Un complexe multisports tout neuf pour Acton Vale          2021-05-16
# ...                                                   ...                 ...
# 490516  Accident de travail chez Domtar : la Ville de ...          2021-10-26
# 490517  À cause de la sécheresse, Hydro-Manitoba prévo...          2021-11-10
# 490518  Budget de l'Ontario : des années de déficits a...          2021-03-24
# 490519      Kruger veut bâtir un entrepôt géant à Windsor          2021-11-13
# 490520      Le pétrole embellit les finances de l'Alberta          2021-08-31
#
#        Journée de différence  \
# 0                        189
# 1                        132
# 2                        157
# 3                         33
# 4                         79
# ...                      ...
# 490516                    53
# 490517                    38
# 490518                   269
# 490519                    35
# 490520                   109
#
#                                                       URL  \
# 0       https://vingt55.ca/un-motoneigiste-blesse-recu...
# 1       https://www.latribune.ca/actualites/justice-et...
# 2       https://vingt55.ca/accident-delit-de-fuite-et-...
# 3       https://www.tvanouvelles.ca/2021/07/01/la-sq-d...
# 4       https://www.lavoixdelest.ca/actualites/un-comp...
# ...                                                   ...
# 490516  https://www.latribune.ca/2021/10/26/accident-d...
# 490517  https://ici.radio-canada.ca/nouvelle/1838944/s...
# 490518  https://ici.radio-canada.ca/nouvelle/1779713/b...
# 490519  https://www.latribune.ca/2021/11/13/kruger-veu...
# 490520  https://ici.radio-canada.ca/nouvelle/1820608/m...
#
#        date et heure saisie type mot-clés            media_url
# 0       2021-08-03 16:00:10         local           vingt55.ca
# 1       2021-08-03 16:00:11         local     www.latribune.ca
# 2       2021-08-03 16:00:11         local           vingt55.ca
# 3       2021-08-03 16:00:11         local  www.tvanouvelles.ca
# 4       2021-08-03 16:00:11         local  www.lavoixdelest.ca
# ...                     ...           ...                  ...
# 490516  2021-12-18 14:11:12      national     www.latribune.ca
# 490517  2021-12-18 14:11:12      national  ici.radio-canada.ca
# 490518  2021-12-18 14:11:12      national  ici.radio-canada.ca
# 490519  2021-12-18 14:11:12      national     www.latribune.ca
# 490520  2021-12-18 14:11:13      national  ici.radio-canada.ca
#
# [490521 rows x 11 columns]

# %%
listemedia
# Out:
#                       media_url      Type_media Ville du siège social  \
# 0           ici.radio-canada.ca        national              Montréal
# 1               www.lapresse.ca        national              Montréal
# 2     www.journaldemontreal.com        national              Montréal
# 3       www.journaldequebec.com        national                Québec
# 4              www.lesoleil.com  local/regional                Québec
# ...                         ...             ...                   ...
# 1454           www.fredzone.org     hors Québec           hors Québec
# 1455          www.info-tours.fr       non media                   NaN
# 1456           www.artsixmic.fr     hors Québec           hors Québec
# 1457           www.handirect.fr     hors Québec           hors Québec
# 1458            www.arabnews.fr     hors Québec           hors Québec
#
#                     domaine
# 0       ici.radio-canada.ca
# 1               lapresse.ca
# 2     journaldemontreal.com
# 3       journaldequebec.com
# 4              lesoleil.com
# ...                     ...
# 1454       www.fredzone.org
# 1455      www.info-tours.fr
# 1456       www.artsixmic.fr
# 1457       www.handirect.fr
# 1458        www.arabnews.fr
#
# [1459 rows x 4 columns]

# %% [markdown]
# **Création du fichier de la BD avec toutes les données nécessaires.**

# %%
complete_data = full_data.merge(listemedia, on = "media_url", how = "left")

# %%
complete_data.to_csv("fulldata_google-news_VF.csv", index=False)

# %% [markdown]
# # Volume de médias local/régional vs. national vs. non media vs. hors-québec

# %%
complete_data["Type_media"].value_counts()
# Out:
# local/regional    227919
# national          212886
# non media          25298
# hors Québec        21900
# to_drop             2512
# Name: Type_media, dtype: int64

# %%
complete_data["Ville du siège social"].value_counts()
# Out:
# Montréal                      187555
# Québec                         47694
# hors Québec                    22545
# Trois-Rivières                 21500
# Sherbrooke                     16622
#                                ...
# Kirkland                          33
# Saint-Bruno-de-Montarville        20
# Coteau-du-Lac                     11
# Chandler                           4
# Chénéville                         2
# Name: Ville du siège social, Length: 75, dtype: int64

# %%
complete_data["domaine"].value_counts()
# Out:
# ici.radio-canada.ca            82422
# lapresse.ca                    29768
# journaldemontreal.com          28872
# journaldequebec.com            25776
# lesoleil.com                   20681
#                                ...
# www.rtn.ch                         1
# www.lavoixdelain.fr                1
# www.lejournaldemontreuil.fr        1
# www.fredzone.org                   1
# www.arabnews.fr                    1
# Name: domaine, Length: 1426, dtype: int64
